# %% [markdown]
# # Pixar Web Scrape
#
# ### We will need to create a data set
#
# To gather the Pixar movie information we will scrape the IMDB movie database. We will begin by importinging beautiful soup, pandas and requests.

# %%
import bs4
import pandas as pd
import requests
import numpy as np

# %% [markdown]
# We will create a function that will extract the html on a webpage into a BeautifulSoup object.

# %%
def get_page_contents(url):
    page = requests.get(url, headers={"Accept-Language": "en-US"})
    return bs4.BeautifulSoup(page.text, "html.parser")

# %% [markdown]
# Next we will create a few more functions to scrape numeric movie data, text values and nested values.

# %%
def numeric_value(movie, tag, class_=None, order=None):
    if order:
        if len(movie.findAll(tag, class_)) > 1:
            to_extract = movie.find_all(tag, class_)[order]['data-value']
        else:
            to_extract = None
    else:
        to_extract = movie.find(tag, class_)['data-value']

    return to_extract

# %%
def text_value(movie, tag, class_=None):
    if movie.find(tag, class_):
        return movie.find(tag, class_).text
    else:
        return

# %%
def nested_text_value(movie, tag_1, class_1, tag_2, class_2, order=None):
    if not order:
        try:
            return movie.find(tag_1, class_1).find(tag_2, class_2).text
        except:
            return ""
    else:
        return [val.text for val in movie.find(tag_1, class_1).findAll(tag_2, class_2)[order]]

# %% [markdown]
# We will now create a function that will run the previous functions depending on need.

# %%
def extract_attribute(soup, tag_1, class_1='', tag_2='', class_2='',
                      text_attribute=True, order=None, nested=False):
    movies = soup.findAll('div', class_='lister-item-content')
    data_list = []
    for movie in movies:
        if text_attribute:
            if nested:
                data_list.append(nested_text_value(movie, tag_1, class_1, tag_2, class_2, order))
            else:
                data_list.append(text_value(movie, tag_1, class_1))
        else:
            data_list.append(numeric_value(movie, tag_1, class_1, order))

    return data_list

# %% [markdown]
# Our final function will create a dictionary with the information scraped as well as two functions to handle specific cases not covered by our previous functions.

# %%
def create_dict():
    title = extract_attribute(soup, 'a')
    release = extract_attribute(soup, 'span', 'lister-item-year text-muted unbold')
    audience_rating = extract_attribute(soup, 'span', 'certificate')
    runtime = extract_attribute(soup, 'span', 'runtime')
    genre = extract_attribute(soup, 'span', 'genre')
    imdb_rating = extract_attribute(soup, 'div', 'inline-block ratings-imdb-rating', False)
    metascore = extract_attribute(soup, 'div', 'inline-block ratings-metascore', False)
    directors = extract_attribute(soup, 'p', '', 'a', '', True, 0, True)
    actors = extract_attribute(soup, 'p', '', 'a', '', True, slice(1, 5, None), True)
    
    movies = soup.findAll('div', class_='lister-item-content')
    imdb_id = []
    for movie in movies:
        imdb_id.append(soup.find('h3').a['href'].split('/')[2])
    
    movies = soup.findAll('div', class_='lister-item-content')
    description = []
    for movie in movies:
        description.append(movie.findAll('p', class_='text-muted')[-1].text.lstrip())
        
    movies = soup.findAll('div', class_='lister-item-content')
    votes = []
    earnings = []
    
    for movie in movies:
        movie_numbers = movie.findAll("span",attrs={"name": "nv"})
        if len(movie_numbers) == 2:
            votes.append(movie_numbers[0].text)
            earnings.append(movie_numbers[1].text)
        elif len(movie_numbers) == 1:
            votes.append(movie_numbers[0].text)
            earnings.append("")
        else:
            votes.append("")
            earnings.append("")
  
            
    
    df_dict = {'IMDB ID': imdb_id, 'Title': title, 'Year': release, 'Audience Rating': audience_rating,
           'Runtime': runtime, 'Genre': genre, 'IMDB Rating': imdb_rating,
           'Votes': votes, 'Box Office Earnings': earnings, 'Description' : description, 'Metascore': metascore, 'Director': directors,
           'Actors': actors}
    
    return df_dict

# %% [markdown]
# We will now run the get_page_contents function and connect to a IMDB pixar movie list.

# %%
soup = get_page_contents('https://www.imdb.com/list/ls087116422/')

df_dict2 = {}
df_dict2.update(create_dict())

# %%
df = pd.DataFrame(df_dict2)
df
# Out:
#       IMDB ID                Title        Year Audience Rating  Runtime  \
# 0   tt0114709            Toy Story      (1995)               G   81 min
# 1   tt0114709          Toy Story 2      (1999)               G   92 min
# 2   tt0114709          Toy Story 3      (2010)               G  103 min
# 3   tt0114709          Toy Story 4      (2019)               G  100 min
# 4   tt0114709         A Bug's Life      (1998)               G   95 min
# 5   tt0114709      The Incredibles      (2004)              PG  115 min
# 6   tt0114709    The Incredibles 2      (2018)              PG  118 min
# 7   tt0114709         Finding Nemo      (2003)               G  100 min
# 8   tt0114709         Finding Dory      (2016)              PG   97 min
# 9   tt0114709           Inside Out  (I) (2015)              PG   95 min
# 10  tt0114709                 Coco  (I) (2017)              PG  105 min
# 11  tt0114709  Monsters University      (2013)               G  104 min
# 12  tt0114709       Monsters, Inc.      (2001)               G   92 min
# 13  tt0114709                   Up      (2009)              PG   96 min
# 14  tt0114709          Ratatouille      (2007)               G  111 min
# 15  tt0114709                Brave      (2012)              PG   93 min
# 16  tt0114709                 Cars      (2006)               G  117 min
# 17  tt0114709               Cars 2      (2011)               G  106 min
# 18  tt0114709               Onward  (I) (2020)              PG  102 min
# 19  tt0114709    The Good Dinosaur      (2015)              PG   93 min
# 20  tt0114709               Cars 3      (2017)               G  102 min
# 21  tt0114709               WALL·E      (2008)               G   98 min
#
#                                          Genre IMDB Rating    Votes  \
# 0   \nAnimation, Adventure, Comedy                    None  860,844
# 1   \nAnimation, Adventure, Comedy                    None  512,617
# 2   \nAnimation, Adventure, Comedy                    None  736,991
# 3   \nAnimation, Adventure, Comedy                    None  186,520
# 4   \nAnimation, Adventure, Comedy                    None  260,535
# 5   \nAnimation, Action, Adventure                    None  640,491
# 6   \nAnimation, Action, Adventure                    None  237,642
# 7   \nAnimation, Adventure, Comedy                    None  924,523
# 8   \nAnimation, Adventure, Comedy                    None  232,355
# 9   \nAnimation, Adventure, Comedy                    None  589,378
# 10  \nAnimation, Adventure, Family                    None  348,294
# 11  \nAnimation, Adventure, Comedy                    None  312,769
# 12  \nAnimation, Adventure, Comedy                    None  791,932
# 13  \nAnimation, Adventure, Comedy                    None  907,716
# 14  \nAnimation, Adventure, Comedy                    None  622,181
# 15  \nAnimation, Adventure, Comedy                    None  362,942
# 16     \nAnimation, Comedy, Family                    None  356,235
# 17  \nAnimation, Adventure, Comedy                    None  154,097
# 18  \nAnimation, Adventure, Comedy                    None   72,601
# 19  \nAnimation, Adventure, Comedy                    None   98,822
# 20  \nAnimation, Adventure, Comedy                    None   70,835
# 21  \nAnimation, Adventure, Family                    None  970,830
#
#    Box Office Earnings                            Description  \
# 0             $191.80M  Votes:\n860,844\n| Gross:\n$191.80M\n
# 1             $245.85M  Votes:\n512,617\n| Gross:\n$245.85M\n
# 2             $415.00M  Votes:\n736,991\n| Gross:\n$415.00M\n
# 3             $434.04M  Votes:\n186,520\n| Gross:\n$434.04M\n
# 4             $162.80M  Votes:\n260,535\n| Gross:\n$162.80M\n
# 5             $261.44M  Votes:\n640,491\n| Gross:\n$261.44M\n
# 6             $608.58M  Votes:\n237,642\n| Gross:\n$608.58M\n
# 7             $380.84M  Votes:\n924,523\n| Gross:\n$380.84M\n
# 8             $486.30M  Votes:\n232,355\n| Gross:\n$486.30M\n
# 9             $356.46M  Votes:\n589,378\n| Gross:\n$356.46M\n
# 10            $209.73M  Votes:\n348,294\n| Gross:\n$209.73M\n
# 11            $268.49M  Votes:\n312,769\n| Gross:\n$268.49M\n
# 12            $289.92M  Votes:\n791,932\n| Gross:\n$289.92M\n
# 13            $293.00M  Votes:\n907,716\n| Gross:\n$293.00M\n
# 14            $206.45M  Votes:\n622,181\n| Gross:\n$206.45M\n
# 15            $237.28M  Votes:\n362,942\n| Gross:\n$237.28M\n
# 16            $244.08M  Votes:\n356,235\n| Gross:\n$244.08M\n
# 17            $191.45M  Votes:\n154,097\n| Gross:\n$191.45M\n
# 18             $61.56M    Votes:\n72,601\n| Gross:\n$61.56M\n
# 19            $123.09M   Votes:\n98,822\n| Gross:\n$123.09M\n
# 20            $152.90M   Votes:\n70,835\n| Gross:\n$152.90M\n
# 21            $223.81M  Votes:\n970,830\n| Gross:\n$223.81M\n
#
#                                     Metascore Director Actors
# 0   \n95        \n        Metascore\n                      []
# 1   \n88        \n        Metascore\n                      []
# 2   \n92        \n        Metascore\n                      []
# 3   \n84        \n        Metascore\n                      []
# 4   \n77        \n        Metascore\n                      []
# 5   \n90        \n        Metascore\n                      []
# 6   \n80        \n        Metascore\n                      []
# 7   \n90        \n        Metascore\n                      []
# 8   \n77        \n        Metascore\n                      []
# 9   \n94        \n        Metascore\n                      []
# 10  \n81        \n        Metascore\n                      []
# 11  \n65        \n        Metascore\n                      []
# 12  \n79        \n        Metascore\n                      []
# 13  \n88        \n        Metascore\n                      []
# 14  \n96        \n        Metascore\n                      []
# 15  \n69        \n        Metascore\n                      []
# 16  \n73        \n        Metascore\n                      []
# 17  \n57        \n        Metascore\n                      []
# 18  \n61        \n        Metascore\n                      []
# 19  \n66        \n        Metascore\n                      []
# 20  \n59        \n        Metascore\n                      []
# 21  \n95        \n        Metascore\n                      []

# %% [markdown]
# We will now clean the data.

# %%
clean_df = df

# %%
clean_df['Year'] = clean_df['Year'].str.slice(start=-5, stop=-1)

# %%
clean_df['IMDB Rating'] = clean_df['IMDB Rating'].str.replace('\n',"")

# %%
clean_df['Metascore'] = clean_df['Metascore'].str.replace('\n',"")
clean_df['Metascore'] = clean_df['Metascore'].str.replace('Metascore',"")

# %%
clean_df['Runtime'] = clean_df['Runtime'].str.replace('min',"")

# %%
clean_df['Genre'] = clean_df['Genre'].str.slice(start=1)

# %%
clean_df['Studio'] = "Pixar Animation Studio"

# %%
clean_df.head()
# Out:
#      IMDB ID         Title  Year Audience Rating Runtime  \
# 0  tt0114709     Toy Story  1995               G     81
# 1  tt0114709   Toy Story 2  1999               G     92
# 2  tt0114709   Toy Story 3  2010               G    103
# 3  tt0114709   Toy Story 4  2019               G    100
# 4  tt0114709  A Bug's Life  1998               G     95
#
#                                       Genre IMDB Rating    Votes  \
# 0  Animation, Adventure, Comedy                    None  860,844
# 1  Animation, Adventure, Comedy                    None  512,617
# 2  Animation, Adventure, Comedy                    None  736,991
# 3  Animation, Adventure, Comedy                    None  186,520
# 4  Animation, Adventure, Comedy                    None  260,535
#
#   Box Office Earnings                            Description  \
# 0            $191.80M  Votes:\n860,844\n| Gross:\n$191.80M\n
# 1            $245.85M  Votes:\n512,617\n| Gross:\n$245.85M\n
# 2            $415.00M  Votes:\n736,991\n| Gross:\n$415.00M\n
# 3            $434.04M  Votes:\n186,520\n| Gross:\n$434.04M\n
# 4            $162.80M  Votes:\n260,535\n| Gross:\n$162.80M\n
#
#                     Metascore Director Actors                  Studio
# 0  95                                      []  Pixar Animation Studio
# 1  88                                      []  Pixar Animation Studio
# 2  92                                      []  Pixar Animation Studio
# 3  84                                      []  Pixar Animation Studio
# 4  77                                      []  Pixar Animation Studio

# %%
clean_df = clean_df[['IMDB ID', 'Title', 'Year', 'Genre', 'Audience Rating', 'Description', 'Studio', 'Director', 'Actors', 'Box Office Earnings', 'Metascore', 'IMDB Rating', 'Votes']]

# %% [markdown]
# Now that we are done we will save the file.

# %%
save_path = r"C:\Users\Basil\Documents\Data Science\Projects\20200521 Disney\1. Original Data\Pixar Animation Studios.csv"
clean_df.to_csv(save_path)
