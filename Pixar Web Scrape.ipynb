# %% [markdown]
# # Pixar Web Scrape
#
# ### We will need to create a data set
#
# To gather the Pixar movie information we will scrape the IMDB movie database. We will begin by importinging beautiful soup, pandas and requests.

# %%
import bs4
import pandas as pd
import requests

# %% [markdown]
# We will create a function that will extract the html on a webpage into a BeautifulSoup object.

# %%
def get_page_contents(url):
    page = requests.get(url, headers={"Accept-Language": "en-US"})
    return bs4.BeautifulSoup(page.text, "html.parser")

# %% [markdown]
# Next we will create a few more functions to scrape numeric movie data, text values and nested values.

# %%
def numeric_value(movie, tag, class_=None, order=None):
    if order:
        if len(movie.findAll(tag, class_)) > 1:
            to_extract = movie.findAll(tag, class_)[order]['data-value']
        else:
            to_extract = None
    else:
        to_extract = movie.find(tag, class_)['data-value']

    return to_extract

# %%
def text_value(movie, tag, class_=None):
    if movie.find(tag, class_):
        return movie.find(tag, class_).text
    else:
        return

# %%
def nested_text_value(movie, tag_1, class_1, tag_2, class_2, order=None):
    if not order:
        try:
            return movie.find(tag_1, class_1).find(tag_2, class_2).text
        except:
            return ""
    else:
        return [val.text for val in movie.find(tag_1, class_1).findAll(tag_2, class_2)[order]]

# %% [markdown]
# We will now create a function that will run the previous functions depending on need.

# %%
def extract_attribute(soup, tag_1, class_1='', tag_2='', class_2='',
                      text_attribute=True, order=None, nested=False):
    movies = soup.findAll('div', class_='lister-item-content')
    data_list = []
    for movie in movies:
        if text_attribute:
            if nested:
                data_list.append(nested_text_value(movie, tag_1, class_1, tag_2, class_2, order))
            else:
                data_list.append(text_value(movie, tag_1, class_1))
        else:
            data_list.append(numeric_value(movie, tag_1, class_1, order))

    return data_list

# %% [markdown]
# Our final function will create a dictionary with the information scraped as well as two functions to handle specific cases not covered by our previous functions.

# %%
def create_dict():
    title = extract_attribute(soup, 'a')
    release = extract_attribute(soup, 'span', 'lister-item-year text-muted unbold')
    audience_rating = extract_attribute(soup, 'span', 'certificate')
    runtime = extract_attribute(soup, 'span', 'runtime')
    genre = extract_attribute(soup, 'span', 'genre')
    imdb_rating = extract_attribute(soup, 'div', 'inline-block ratings-imdb-rating', False)
    metascore = extract_attribute(soup, 'div', 'inline-block ratings-metascore', False)
    votes = extract_attribute(soup, 'span' , {'name' : 'nv'}, False, 0)
    earnings = extract_attribute(soup, 'span' , {'name' : 'nv'}, False, 1)
    directors = extract_attribute(soup, 'p', '', 'a', '', True, 0, True)
    actors = extract_attribute(soup, 'p', '', 'a', '', True, slice(1, 5, None), True)
    
    movies = soup.findAll('div', class_='lister-item-content')
    imdb_id = []
    for movie in movies:
        imdb_id.append(soup.find('h3').a['href'].split('/')[2])
    
    movies = soup.findAll('div', class_='lister-item-content')
    description = []
    for movie in movies:
        description.append(movie.findAll('p', class_='text-muted')[-1].text.lstrip())
    
    df_dict = {'IMDB ID': imdb_id, 'Title': title, 'Year': release, 'Audience Rating': audience_rating,
           'Runtime': runtime, 'Genre': genre, 'IMDB Rating': imdb_rating,
# 0               PG  102 min  \nAnimation, Adventure, Comedy
# 1                R  113 min          \nAction, Crime, Drama
# 2                G  100 min  \nAnimation, Adventure, Comedy
# 3               PG  105 min  \nAnimation, Adventure, Family
# 4                G  117 min     \nAnimation, Comedy, Family
# 5               PG   95 min  \nAnimation, Adventure, Comedy
# 6             None   90 min  \nAnimation, Adventure, Comedy
# 7                G  111 min  \nAnimation, Adventure, Comedy
# 8               PG  118 min  \nAnimation, Action, Adventure
# 9               PG  115 min  \nAnimation, Action, Adventure
# 10               G   81 min  \nAnimation, Adventure, Comedy
# 11               G  100 min  \nAnimation, Adventure, Comedy
# 12              PG   96 min  \nAnimation, Adventure, Comedy
# 13           PG-13  187 min      \nAction, Adventure, Drama
# 14               G   92 min  \nAnimation, Adventure, Comedy
# 15               G   98 min  \nAnimation, Adventure, Family
# 16               G  103 min  \nAnimation, Adventure, Comedy
# 17               G   95 min  \nAnimation, Adventure, Comedy
# 18              PG   93 min  \nAnimation, Adventure, Comedy
# 19              PG  101 min  \nAnimation, Adventure, Comedy
# 20               G   84 min    \nAnimation, Family, Fantasy
# 21               G  101 min  \nAnimation, Adventure, Comedy
# 22           PG-13  132 min     \nAction, Adventure, Sci-Fi
# 23              PG   97 min  \nAnimation, Adventure, Comedy
# 24               G   92 min  \nAnimation, Adventure, Comedy
# 25               G  102 min  \nAnimation, Adventure, Comedy
# 26               G  104 min  \nAnimation, Adventure, Comedy
# 27               G  106 min  \nAnimation, Adventure, Comedy
# 28              PG   93 min  \nAnimation, Adventure, Comedy
# 29              PG  104 min     \nAdventure, Comedy, Family
# 30            TV-Y   55 min  \nAnimation, Adventure, Comedy
# 31           PG-13  109 min   \nAdventure, Fantasy, Mystery
# 32               G   77 min   \nAnimation, Adventure, Crime
# 33              PG  103 min     \nAction, Adventure, Sci-Fi
# 34            E10+     None     \nAction, Adventure, Comedy
# 35              PG  106 min    \nAction, Adventure, Mystery
# 36              PG   91 min  \nAnimation, Adventure, Comedy
# 37               G   75 min    \nAnimation, Family, Fantasy
# 38            None     None  \nAnimation, Adventure, Comedy
# 39            TV-G    3 min      \nAnimation, Short, Comedy
# 40            TV-G   22 min   \nAnimation, Short, Adventure
# 41            TV-G     None    \nComedy, Family, Reality-TV
# 42              PG    9 min      \nAnimation, Short, Comedy
# 43            TV-G   22 min   \nAnimation, Short, Adventure
# 44               G    6 min      \nAnimation, Short, Family
# 45           TV-14  134 min                        \nComedy
# 46               G    8 min      \nAnimation, Short, Family
# 47            None    7 min   \nAnimation, Short, Adventure
# 48               E     None             \nAdventure, Family
# 49           TV-Y7   30 min  \nAnimation, Action, Adventure
#
#    IMDB Rating    Votes Box Office Earnings  \
# 0    \n\n7.5\n   70,107              70,107
# 1    \n\n7.6\n  416,911             416,911
# 2    \n\n7.8\n  184,996             184,996
# 3    \n\n8.4\n  346,051             346,051
# 4    \n\n7.1\n  355,337             355,337
# 5    \n\n8.1\n  587,600             587,600
# 6         None     None                None
# 7    \n\n8.0\n  620,890             620,890
# 8    \n\n7.6\n  236,615             236,615
# 9    \n\n8.0\n  639,378             639,378
# 10   \n\n8.3\n  858,992             858,992
# 11   \n\n8.1\n  922,773             922,773
# 12   \n\n8.2\n  905,775             905,775
# 13   \n\n7.2\n  382,831             382,831
# 14   \n\n8.0\n  790,366             790,366
# 15   \n\n8.4\n  968,717             968,717
# 16   \n\n8.3\n  735,511             735,511
# 17   \n\n7.2\n  260,149             260,149
# 18   \n\n7.1\n  362,187             362,187
# 19   \n\n7.7\n  369,341             369,341
# 20   \n\n8.0\n  408,839             408,839
# 21   \n\n7.7\n  118,624             118,624
# 22   \n\n6.6\n  251,002             251,002
# 23   \n\n7.3\n  231,732             231,732
# 24   \n\n7.9\n  511,643             511,643
# 25   \n\n6.7\n   70,471              70,471
# 26   \n\n7.3\n  312,129             312,129
# 27   \n\n6.1\n  153,600             153,600
# 28   \n\n6.7\n   98,578              98,578
# 29   \n\n4.1\n   47,674              47,674
# 30   \n\n8.1\n   11,619              11,619
# 31   \n\n6.8\n   18,636              18,636
# 32   \n\n6.9\n   37,045              37,045
# 33   \n\n6.4\n   68,942              68,942
# 34   \n\n8.6\n    1,395               1,395
# 35   \n\n6.0\n   80,718              80,718
# 36   \n\n5.4\n    5,580               5,580
# 37   \n\n7.1\n   10,326              10,326
# 38        None     None                None
# 39   \n\n6.9\n      899                 899
# 40   \n\n7.2\n    9,436               9,436
# 41   \n\n6.5\n      288                 288
# 42   \n\n7.7\n      677                 677
# 43   \n\n7.5\n   13,030              13,030
# 44   \n\n8.4\n   24,497              24,497
# 45   \n\n7.0\n      564                 564
# 46   \n\n7.5\n   20,291              20,291
# 47   \n\n6.7\n    1,333               1,333
# 48   \n\n7.5\n      480                 480
# 49   \n\n6.7\n    2,678               2,678
#
#                                           Description  \
# 0   Two elven brothers embark on a quest to bring ...
# 1   After being coerced into working for a crime b...
# 2   When a new toy called "Forky" joins Woody and ...
# 3   Aspiring musician Miguel, confronted with his ...
# 4   A hot-shot race-car named Lightning McQueen ge...
# 5   After young Riley is uprooted from her Midwest...
# 6   A musician who has lost his passion for music ...
# 7   A rat who can cook makes an unusual alliance w...
# 8   The Incredibles hero family takes on a new mis...
# 9   A family of undercover superheroes, while tryi...
# 10  A cowboy doll is profoundly threatened and jea...
# 11  After his son is captured in the Great Barrier...
# 12  78-year-old Carl Fredricksen travels to Paradi...
# 13  A greedy film producer assembles a team of mov...
# 14  In order to power the city, monsters have to s...
# 15  In the distant future, a small waste-collectin...
# 16  The toys are mistakenly delivered to a day-car...
# 17  A misfit ant, looking for "warriors" to save h...
# 18  Determined to make her own path in life, Princ...
# 19  A video game villain wants to be a hero and se...
# 20  A prince cursed to spend his days as a hideous...
# 21  A five-year-old boy develops a relationship wi...
# 22  Transported to Barsoom, a Civil War vet discov...
# 23  Friendly but forgetful blue tang Dory begins a...
# 24  When Woody is stolen by a toy collector, Buzz ...
# 25  Lightning McQueen sets out to prove to a new g...
# 26  A look at the relationship between Mike Wazows...
# 27  Star race car Lightning McQueen and his pal Ma...
# 28  In a world where dinosaurs and humans live sid...
# 29  Two Brooklyn plumbers, Mario and Luigi, must t...
# 30  On a special inner city street, the inhabitant...
# 31  When assorted people start having inexplicable...
# 32  The R.A.S. agents, Miss Bianca and Bernard, ra...
# 33  When the crew of the Enterprise learn of a Fed...
# 34  Believing light and darkness must remain in ba...
# 35  After New York City receives a series of attac...
# 36  Following the events of the first movie, Surly...
# 37  Tinkerbell wanders into the forbidden Winter w...
# 38  A Monsters inc series set 6 months after the M...
# 39  Forky asks important questions about how the w...
# 40  It's a post-Christmas play-date and the toys h...
# 41  This live action series brings iconic characte...
# 42  On an average day, Greg's life is filled with ...
# 43  Woody and the gang are held up at a roadside m...
# 44  A mother bird tries to teach her little one ho...
# 45  Awards ceremony celebrating the best in TV and...
# 46  A Chinese-Canadian woman suffering from empty ...
# 47  Short that shows what happened to Bo Peep and ...
# 48  A nice food-loving rat makes his way to a rest...
# 49  The further adventures of Buzz Lightyear as a ...
#
#                                         Metascore            Director  \
# 0   \n61        \n        Metascore\n                     Dan Scanlon
# 1   \n86        \n        Metascore\n                    Edgar Wright
# 2   \n84        \n        Metascore\n                     Josh Cooley
# 3   \n81        \n        Metascore\n                     Lee Unkrich
# 4   \n73        \n        Metascore\n                   John Lasseter
# 5   \n94        \n        Metascore\n                     Pete Docter
# 6                                            None         Pete Docter
# 7   \n96        \n        Metascore\n                       Brad Bird
# 8   \n80        \n        Metascore\n                       Brad Bird
# 9   \n90        \n        Metascore\n                       Brad Bird
# 10  \n95        \n        Metascore\n                   John Lasseter
# 11  \n90        \n        Metascore\n                  Andrew Stanton
# 12  \n88        \n        Metascore\n                     Pete Docter
# 13  \n81        \n        Metascore\n                   Peter Jackson
# 14  \n79        \n        Metascore\n                     Pete Docter
# 15  \n95        \n        Metascore\n                  Andrew Stanton
# 16  \n92        \n        Metascore\n                     Lee Unkrich
# 17  \n77        \n        Metascore\n                   John Lasseter
# 18  \n69        \n        Metascore\n                    Mark Andrews
# 19  \n72        \n        Metascore\n                      Rich Moore
# 20  \n95        \n        Metascore\n                  Gary Trousdale
# 21  \n86        \n        Metascore\n                  Hayao Miyazaki
# 22  \n51        \n        Metascore\n                  Andrew Stanton
# 23  \n77        \n        Metascore\n                  Andrew Stanton
# 24  \n88        \n        Metascore\n                   John Lasseter
# 25  \n59        \n        Metascore\n                       Brian Fee
# 26  \n65        \n        Metascore\n                     Dan Scanlon
# 27  \n57        \n        Metascore\n                   John Lasseter
# 28  \n66        \n        Metascore\n                      Peter Sohn
# 29                                           None      Annabel Jankel
# 30                                           None          Jim Henson
# 31  \n65        \n        Metascore\n                  Barry Levinson
# 32  \n70        \n        Metascore\n                    Hendel Butoy
# 33  \n64        \n        Metascore\n                 Jonathan Frakes
# 34                                           None      Tetsuya Nomura
# 35  \n64        \n        Metascore\n                    Kerry Conran
# 15                 \nAction, Sport               \n\n7.0\n   1,046
# 16   \nAnimation, Short, Adventure               \n\n7.7\n   9,889
# 17      \nAnimation, Short, Comedy               \n\n8.0\n  28,378
# 18      \nAnimation, Short, Action               \n\n7.1\n   1,217
# 19     \nAnimation, Comedy, Family               \n\n6.7\n     336
# 20       \nAnimation, Short, Drama               \n\n8.0\n   4,121
# 21      \nAnimation, Short, Family               \n\n8.0\n  12,741
# 22   \nAnimation, Short, Adventure               \n\n7.6\n  14,050
# 23      \nAnimation, Short, Comedy               \n\n7.0\n  12,492
# 24  \nDocumentary, History, Sci-Fi               \n\n8.3\n   3,903
# 25      \nAnimation, Short, Family               \n\n7.9\n  22,099
# 26   \nAnimation, Short, Adventure               \n\n7.1\n   1,634
# 27      \nAnimation, Short, Family               \n\n6.5\n   9,387
# 28  \nAnimation, Action, Adventure               \n\n7.6\n     521
# 29     \nAction, Adventure, Family               \n\n7.4\n     506
# 30      \nAnimation, Short, Family               \n\n7.6\n   8,524
# 31      \nAnimation, Short, Comedy               \n\n7.1\n  11,977
# 32      \nAnimation, Short, Family               \n\n6.2\n   1,288
# 33      \nAnimation, Short, Family               \n\n7.3\n  12,638
# 34      \nAnimation, Short, Comedy               \n\n8.2\n  19,498
# 35      \nAnimation, Short, Comedy               \n\n6.6\n   7,246
# 36      \nAnimation, Short, Comedy               \n\n7.9\n   5,819
# 37                \nAction, Family               \n\n7.5\n   1,838
# 38      \nAnimation, Short, Family               \n\n5.3\n   4,913
# 39      \nAnimation, Short, Comedy               \n\n8.3\n  22,107
# 40      \nAnimation, Short, Comedy               \n\n7.7\n  14,359
# 41  \nAnimation, Action, Adventure               \n\n7.4\n   1,103
# 42      \nAnimation, Short, Comedy               \n\n7.5\n  12,744
# 43      \nAnimation, Short, Comedy               \n\n7.8\n  17,468
# 44      \nAnimation, Short, Family               \n\n6.3\n   6,269
# 45   \nAnimation, Short, Adventure               \n\n7.1\n     516
# 46      \nAnimation, Short, Comedy               \n\n6.0\n     512
# 47      \nAnimation, Short, Comedy               \n\n7.1\n   5,022
# 48      \nAnimation, Short, Comedy               \n\n7.0\n   5,354
# 49      \nAction, Adventure, Drama               \n\n7.2\n     508
#
#    Box Office Earnings                                        Description  \
# 0                5,541  A fast food restaurant mini variant of Buzz fo...
# 1                  559  In LOOP, two kids at canoe camp find themselve...
# 2                2,555  Cruise into the crazy adventures of Tow Mater ...
# 3                  864  An exploration of the history and emotional po...
# 4                5,752  During the Depression, Jimmy Gralton returns h...
# 5               14,171  A story that takes place over millions of year...
# 6                4,043  Buzz Lightyear must battle Emperor Zurg with t...
# 7                  207  A new game where players take control of their...
# 8                5,829  Riley, now 12, who is hanging out with her par...
# 9                1,982  An earnest ball of yarn named Purl gets a job ...
# 10              16,336  The personifications of daytime and nighttime ...
# 11               5,709  When Rex finds himself left behind in the bath...
# 12               1,306  A father discovers that his son floats, which ...
# 13               7,367  The toys throw Ken and Barbie a Hawaiian vacat...
# 14               2,004  The 88th Academy Awards ceremony honors achiev...
# 15               1,046  After the adventures in the movie, McQueen sta...
# 16               9,889  If BURN-E (a welding robot) had known how much...
# 17              28,378  A group of snooty birds roosting on a telephon...
# 18               1,217      Edna babysits Jack-Jack, who uses his powers.
# 19                 336  A series of shorts featuring the characters ma...
# 20               4,121  An unlikely connection sparks between two crea...
# 21              12,741  A young boy helps his father and grandfather h...
# 22              14,050  The Parrs' baby Jack-Jack is thought to be nor...
# 23              12,492  A sheep dances proudly in his southwestern lan...
# 24               3,903  An in-depth making of documentary about the or...
# 25              22,099  Geri sets up a chess game to play his greatest...
# 26               1,634  With a little trickery, Mike and Sulley help t...
# 27               9,387  A tin one-man-band toy tries to escape a destr...
# 28                 521  Unleash your imagination in this new open worl...
# 29                 506  Woody the cowboy and Buzz Lightyear Space Rang...
# 30               8,524  Amidst the rain in a singing city, two umbrell...
# 31              11,977  Mike's bought a new 6-wheel-drive car, and he ...
# 32               1,288  The witch from Pixar's Brave (2012) uses magic...
# 33              12,638  A larger lamp watches while a smaller, younger...
# 34              19,498  Babies both human and beast are created up in ...
# 35               7,246  In this short featuring the characters of the ...
# 36               5,819  A Pixar short about a lost-and-found box and t...
# 37               1,838  Game players have the chance to join with Buzz...
# 38               4,913  A brainless android wakes up to be taunted by ...
# 39              22,107  A stage magician's rabbit gets into a magical ...
# 40              14,359  Two buskers engage in a petty feud over a chil...
# 41               1,103  A family of undercover superheroes, attempting...
# 42              12,744  A snow globe snowman wants to join the other t...
# 43              17,468  A teenage alien is trying to abduct a sleeping...
# 44               6,269  With a sale tag hanging from his seat, propped...
# 45                 516  Set in a world of magical realism, WIND sees a...
# 46                 512  Interviews with the animals at the Marine Life...
# 47               5,022  Remy and Emile plead the case for rats by illu...
# 48               5,354  Alpha, Beta, and Gamma try to keep Dug out of ...
# 49                 508  From the box-office sleeper, the player can pl...
#
#                                         Metascore             Director  \
# 0                                            None        Angus MacLane
# 1                                            None         Erica Milsom
# 2                                            None  Larry the Cable Guy
# 3   \n80        \n        Metascore\n                     Midge Costin
# 4   \n63        \n        Metascore\n                        Ken Loach
# 5                                            None    James Ford Murphy
# 6                                            None           Tad Stones
# 7                                            None           Pete Gomer
# 8                                            None          Josh Cooley
# 9                                            None       Kristen Lester
# 10                                           None         Teddy Newton
# 11                                           None        Mark A. Walsh
# 12                                           None          Bobby Rubio
# 13                                           None        Gary Rydstrom
# 14                                           None          Glenn Weiss
# 15                                           None  Larry the Cable Guy
# 16                                           None        Angus MacLane
# 17                                           None      Ralph Eggleston
# 18                                           None           Ted Mathot
# 19                                           None        Tony Shalhoub
# 20                                           None      Rosana Sullivan
# 21                                           None      Enrico Casarosa
# 22                                           None            Brad Bird
# 23                                           None           Bud Luckey
# 24                                           None         Edith Becker
# 25                                           None          Jan Pinkava
# 26                                           None          Kelsey Mann
# 27                                           None        John Lasseter
# 28                                           None         Scott Kiraly
# 29                                           None           Jon Burton
# 30                                           None       Saschka Unseld
# 31                                           None          Pete Docter
# 32                                           None         Brian Larsen
# 33                                           None        John Lasseter
# 34                                           None           Peter Sohn
# 35                                           None        John Lasseter
# 36                                           None         Dave Mullins
# 37                                           None            Tim Allen
# 38                                           None       Alvy Ray Smith
# 39                                           None       Doug Sweetland
# 40                                           None         Mark Andrews
# 41                                           None         Shiraz Akmal
# 42                                           None        John Lasseter
# 43                                           None        Gary Rydstrom
# 44                                           None        John Lasseter
# 45                                           None          Edwin Chang
# 46                                           None       Ross Stevenson
# 47                                           None       Jim Capobianco
# 48                                           None    Ronnie Del Carmen
# 49                                           None        Albert Brooks
#
#                                                Actors
# 0   [Dylan Brown, Tom Hanks, Tim Allen, Wallace Sh...
# 1   [Madison Bandy, Christiano Delgado, Louis Gonz...
# 2    [Keith Ferguson, Elissa Knight, Lindsey Collins]
# 3   [Erik Aadahl, Ioan Allen, Richard L. Anderson,...
# 4   [Barry Ward, Francis Magee, Aileen Henry, Simo...
# 5                  [Napua Greig, Kuana Torres Kahele]
# 6   [Tim Allen, Nicole Sullivan, Larry Miller, Ste...
# 7   [Maeve Andrews, Jonathan Banks, John Eric Bent...
# 8   [Pete Docter, Ben Cox, Kyle MacLachlan, Diane ...
# 9   [Bret 'Brook' Parker, Emily Davis, Michael Dal...
# 10                                       [Wayne Dyer]
# 11  [Dylan Brown, Tom Hanks, Tim Allen, Wallace Sh...
# 12  [Eli Fucile, Bobby Rubio, Luna Watson, Mika Kubo]
# 13  [Tom Hanks, Tim Allen, Joan Cusack, Kristen Sc...
# 14  [Chris Rock, Emily Blunt, Charlize Theron, Tom...
# 15        [Corey Burton, Greg Baldwin, George Carlin]
# 16  [Angus MacLane, Tessa Swigart, Ben Burtt, Jeff...
# 17                                  [Ralph Eggleston]
# 18  [Brad Bird, Craig T. Nelson, Eli Fucile, Maeve...
# 19  [Lloyd Sherr, Michael Wallis, Larry the Cable ...
# 20                                                 []
# 21      [Tony Fucile, Krista Sheffler, Phil Sheridan]
# 22  [Bret 'Brook' Parker, Bud Luckey, Eli Fucile, ...
# 23                          [Roger Gould, Bud Luckey]
# 24  [Kevin Burns, Robert Clotworthy, Walter Cronki...
# 25                                     [Bob Peterson]
# 26  [Lori Alan, Carlos Alazraqui, Billy Crystal, C...
# 27                                                 []
# 28  [Lee Unkrich, Jack Angel, Ned Beatty, Charlie ...
# 29  [Corey Burton, R. Lee Ermey, Pat Fraley, Jim H...
# 30                                      [Sarah Jaffe]
# 31         [Roger Gould, Billy Crystal, John Goodman]
# 32     [Julie Walters, Steve Purcell, Callum O'Neill]
# 33                                                 []
# 34                     [Tony Fucile, Lori Richardson]
# 35  [Dan Scanlon, Larry the Cable Guy, Owen Wilson...
# 36                                                 []
# 37               [Jim Hanks, Don Rickles, Jim Varney]
# 38                                                 []
# 39                                   [Doug Sweetland]
# 40                                   [Andrew Jimenez]
# 41  [Jason Lee, Spencer Fox, Sarah Vowell, Corey B...
# 42                                                 []
# 43                                                 []
# 44                                                 []
# 45                   [Emilio Fuentes, Sonoko Konishi]
# 46  [Ty Burrell, Ellen DeGeneres, Idris Elba, Ed O...
# 47  [Patton Oswalt, Peter Sohn, Lou Romano, Tony R...
# 48  [Bob Peterson, Delroy Lindo, Jerome Ranft, Edw...
# 49     [Alexander Gould, Ellen DeGeneres, Erica Beck]

# %% [markdown]
# We will now combine the data from the two pages.

# %%
combined_data = pd.concat([df, df2], ignore_index = True, sort=True)

# %%
clean_df = combined_data

# %% [markdown]
# We will now clean the data.

# %%
clean_df['Year'] = clean_df['Year'].str.slice(start=-5, stop=-1)

# %%
clean_df['IMDB Rating'] = clean_df['IMDB Rating'].str.replace('\n',"")

# %%
clean_df['Metascore'] = clean_df['Metascore'].str.replace('\n',"")
clean_df['Metascore'] = clean_df['Metascore'].str.replace('Metascore',"")

# %%
clean_df['Runtime'] = clean_df['Runtime'].str.replace('min',"")

# %%
clean_df['Genre'] = clean_df['Genre'].str.slice(start=1)

# %%
clean_df['Studio'] = "Pixar Animation Studio"

# %%
clean_df.head()
# Out:
#                                               Actors Audience Rating  \
# 0  [Tom Holland, Chris Pratt, Julia Louis-Dreyfus...              PG
# 1  [Ansel Elgort, Jon Bernthal, Jon Hamm, Eiza Go...               R
# 2     [Tom Hanks, Tim Allen, Annie Potts, Tony Hale]               G
# 3  [Adrian Molina, Anthony Gonzalez, Gael García ...              PG
# 4  [Joe Ranft, Owen Wilson, Bonnie Hunt, Paul New...               G
#
#   Box Office Earnings                                        Description  \
# 0              70,107  Two elven brothers embark on a quest to bring ...
# 1             416,911  After being coerced into working for a crime b...
# 2             184,996  When a new toy called "Forky" joins Woody and ...
# 3             346,051  Aspiring musician Miguel, confronted with his ...
# 4             355,337  A hot-shot race-car named Lightning McQueen ge...
#
#         Director                                     Genre    IMDB ID  \
# 0    Dan Scanlon  Animation, Adventure, Comedy              tt7146812
# 1   Edgar Wright          Action, Crime, Drama              tt7146812
# 2    Josh Cooley  Animation, Adventure, Comedy              tt7146812
# 3    Lee Unkrich  Animation, Adventure, Family              tt7146812
# 4  John Lasseter     Animation, Comedy, Family              tt7146812
#
#   IMDB Rating                       Metascore Runtime        Title    Votes  \
# 0         7.5  61                                102        Onward   70,107
# 1         7.6  86                                113   Baby Driver  416,911
# 2         7.8  84                                100   Toy Story 4  184,996
# 3         8.4  81                                105          Coco  346,051
# 4         7.1  73                                117          Cars  355,337
#
#    Year                  Studio
# 0  2020  Pixar Animation Studio
# 1  2017  Pixar Animation Studio
# 2  2019  Pixar Animation Studio
# 3  2017  Pixar Animation Studio
# 4  2006  Pixar Animation Studio

# %%
clean_df = clean_df[['IMDB ID', 'Title', 'Year', 'Genre', 'Audience Rating', 'Description', 'Studio', 'Director', 'Actors', 'Box Office Earnings', 'Metascore', 'IMDB Rating', 'Votes']]

# %% [markdown]
# Now that we are done we will save the file.

# %%
save_path = r"C:\Users\Basil\Documents\Data Science\Projects\20200521 Disney\1. Original Data\Pixar Animation Studios.csv"
clean_df.to_csv(save_path)
