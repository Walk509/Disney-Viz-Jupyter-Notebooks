# %% [markdown]
# # Pixar Web Scrape
#
# ### We will need to create a data set
#
# To gather the Pixar movie information we will scrape the IMDB movie database. We will begin by importinging beautiful soup, pandas and requests.

# %%
import bs4
import pandas as pd
import requests
import numpy as np

# %% [markdown]
# We will create a function that will extract the html on a webpage into a BeautifulSoup object.

# %%
def get_page_contents(url):
    page = requests.get(url, headers={"Accept-Language": "en-US"})
    return bs4.BeautifulSoup(page.text, "html.parser")

# %% [markdown]
# Next we will create a few more functions to scrape numeric movie data, text values and nested values.

# %%
def numeric_value(movie, tag, class_=None, order=None):
    if order:
        if len(movie.findAll(tag, class_)) > 1:
            to_extract = movie.find_all(tag, class_)[order]['data-value']
        else:
            to_extract = None
    else:
        to_extract = movie.find(tag, class_)['data-value']

    return to_extract

# %%
def text_value(movie, tag, class_=None):
    if movie.find(tag, class_):
        return movie.find(tag, class_).text
    else:
        return

# %%
def nested_text_value(movie, tag_1, class_1, tag_2, class_2, order=None):
    if not order:
        try:
            return movie.find(tag_1, class_1).find(tag_2, class_2).text
        except:
            return ""
    else:
        return [val.text for val in movie.find(tag_1, class_1).findAll(tag_2, class_2)[order]]

# %% [markdown]
# We will now create a function that will run the previous functions depending on need.

# %%
def extract_attribute(soup, tag_1, class_1='', tag_2='', class_2='',
                      text_attribute=True, order=None, nested=False):
    movies = soup.findAll('div', class_='lister-item-content')
    data_list = []
    for movie in movies:
        if text_attribute:
            if nested:
                data_list.append(nested_text_value(movie, tag_1, class_1, tag_2, class_2, order))
            else:
                data_list.append(text_value(movie, tag_1, class_1))
        else:
            data_list.append(numeric_value(movie, tag_1, class_1, order))

    return data_list

# %% [markdown]
# Our final function will create a dictionary with the information scraped as well as two functions to handle specific cases not covered by our previous functions.

# %%
def create_dict():
    title = extract_attribute(soup, 'a')
    release = extract_attribute(soup, 'span', 'lister-item-year text-muted unbold')
    audience_rating = extract_attribute(soup, 'span', 'certificate')
    runtime = extract_attribute(soup, 'span', 'runtime')
    genre = extract_attribute(soup, 'span', 'genre')
    imdb_rating = extract_attribute(soup, 'div', 'inline-block ratings-imdb-rating', False)
    metascore = extract_attribute(soup, 'div', 'inline-block ratings-metascore', False)
    directors = extract_attribute(soup, 'p', '', 'a', '', True, 0, True)
    actors = extract_attribute(soup, 'p', '', 'a', '', True, slice(1, 5, None), True)
    
    movies = soup.findAll('div', class_='lister-item-content')
    imdb_id = []
    for movie in movies:
        imdb_id.append(soup.find('h3').a['href'].split('/')[2])
    
    movies = soup.findAll('div', class_='lister-item-content')
    description = []
    for movie in movies:
        description.append(movie.findAll('p', class_='text-muted')[-1].text.lstrip())
        
    movies = soup.findAll('div', class_='lister-item-content')
    votes = []
    earnings = []
    
    for movie in movies:
        movie_numbers = movie.findAll("span",attrs={"name": "nv"})
        if len(movie_numbers) == 2:
            votes.append(movie_numbers[0].text)
            earnings.append(movie_numbers[1].text)
        elif len(movie_numbers) == 1:
            votes.append(movie_numbers[0].text)
            earnings.append("")
        else:
            votes.append("")
            earnings.append("")
  
            
    
    df_dict = {'IMDB ID': imdb_id, 'Title': title, 'Year': release, 'Audience Rating': audience_rating,
           'Runtime': runtime, 'Genre': genre, 'IMDB Rating': imdb_rating,
           'Votes': votes, 'Box Office Earnings': earnings, 'Description' : description, 'Metascore': metascore, 'Director': directors,
           'Actors': actors}
    
    return df_dict

# %% [markdown]
# We will now run the get_page_contents function and connect to the IMDB Pixar animations studios movie search pages 1 and 2.

# %%
soup = get_page_contents('https://www.imdb.com/search/title/?companies=co0017902&ref_=adv_prv')

df_dict2 = {}
df_dict2.update(create_dict())

# %%
df = pd.DataFrame(df_dict2)
df
# Out:
#       IMDB ID                                  Title               Year  \
# 0   tt7146812                                 Onward         (I) (2020)
# 1   tt7146812                            Baby Driver             (2017)
# 2   tt7146812                            Toy Story 4             (2019)
# 3   tt7146812                                   Cars             (2006)
# 4   tt7146812                                   Coco         (I) (2017)
# 5   tt7146812                            Ratatouille             (2007)
# 6   tt7146812                             Inside Out         (I) (2015)
# 7   tt7146812                                  Brave             (2012)
# 8   tt7146812                      The Incredibles 2             (2018)
# 9   tt7146812                        The Incredibles             (2004)
# 10  tt7146812                           Finding Nemo             (2003)
# 11  tt7146812                              Toy Story             (1995)
# 12  tt7146812                                     Up             (2009)
# 13  tt7146812                         Monsters, Inc.             (2001)
# 14  tt7146812                                Aladdin             (1992)
# 15  tt7146812                                 Cars 3             (2017)
# 16  tt7146812                              King Kong             (2005)
# 17  tt7146812                                 WALL·E             (2008)
# 18  tt7146812                           A Bug's Life             (1998)
# 19  tt7146812                            Toy Story 3             (2010)
# 20  tt7146812                   Beauty and the Beast             (1991)
# 21  tt7146812                         Wreck-It Ralph             (2012)
# 22  tt7146812                            John Carter             (2012)
# 23  tt7146812                    Monsters University             (2013)
# 24  tt7146812                                   Soul             (2020)
# 25  tt7146812                           Finding Dory             (2016)
# 26  tt7146812                            Toy Story 2             (1999)
# 27  tt7146812                                  Ponyo             (2008)
# 28  tt7146812                                 Cars 2             (2011)
# 29  tt7146812                      Super Mario Bros.             (1993)
# 30  tt7146812                      The Good Dinosaur             (2015)
# 31  tt7146812                          Sesame Street           (1969– )
# 32  tt7146812  Sky Captain and the World of Tomorrow             (2004)
# 33  tt7146812                The Rescuers Down Under             (1990)
# 34  tt7146812                Star Trek: Insurrection             (1998)
# 35  tt7146812                     Kingdom Hearts III  (2019 Video Game)
# 36  tt7146812                  Young Sherlock Holmes             (1985)
# 37  tt7146812                    Secret of the Wings             (2012)
# 38  tt7146812                       Monsters at Work           (2020– )
# 39  tt7146812         The Nut Job 2: Nutty by Nature             (2017)
# 40  tt7146812                  Forky Asks a Question           (2019– )
# 41  tt7146812             Toy Story That Time Forgot    (2014 TV Short)
# 42  tt7146812                    Toy Story of Terror    (2013 TV Short)
# 43  tt7146812                     Pixar in Real Life           (2019– )
# 44  tt7146812                                    Bao             (2018)
# 45  tt7146812                                  Piper             (2016)
# 46  tt7146812         Buzz Lightyear of Star Command        (2000–2001)
# 47  tt7146812                              Lamp Life       (2020 Video)
# 48  tt7146812                     Mater's Tall Tales        (2008–2014)
# 49  tt7146812             Toy Story Toons: Small Fry             (2011)
#
#    Audience Rating  Runtime                                       Genre  \
# 0               PG  102 min  \nAnimation, Adventure, Comedy
# 1                R  113 min          \nAction, Crime, Drama
# 2                G  100 min  \nAnimation, Adventure, Comedy
# 3                G  117 min     \nAnimation, Comedy, Family
# 4               PG  105 min  \nAnimation, Adventure, Family
# 5                G  111 min  \nAnimation, Adventure, Comedy
# 6               PG   95 min  \nAnimation, Adventure, Comedy
# 7               PG   93 min  \nAnimation, Adventure, Comedy
# 8               PG  118 min  \nAnimation, Action, Adventure
# 9               PG  115 min  \nAnimation, Action, Adventure
# 10               G  100 min  \nAnimation, Adventure, Comedy
# 11               G   81 min  \nAnimation, Adventure, Comedy
# 12              PG   96 min  \nAnimation, Adventure, Comedy
# 13               G   92 min  \nAnimation, Adventure, Comedy
# 14               G   90 min  \nAnimation, Adventure, Comedy
# 15               G  102 min  \nAnimation, Adventure, Comedy
# 16           PG-13  187 min      \nAction, Adventure, Drama
# 17               G   98 min  \nAnimation, Adventure, Family
# 18               G   95 min  \nAnimation, Adventure, Comedy
# 19               G  103 min  \nAnimation, Adventure, Comedy
# 20               G   84 min    \nAnimation, Family, Fantasy
# 21              PG  101 min  \nAnimation, Adventure, Comedy
# 22           PG-13  132 min     \nAction, Adventure, Sci-Fi
# 23               G  104 min  \nAnimation, Adventure, Comedy
# 24              PG   90 min  \nAnimation, Adventure, Comedy
# 25              PG   97 min  \nAnimation, Adventure, Comedy
# 26               G   92 min  \nAnimation, Adventure, Comedy
# 27               G  101 min  \nAnimation, Adventure, Comedy
# 28               G  106 min  \nAnimation, Adventure, Comedy
# 29              PG  104 min     \nAdventure, Comedy, Family
# 30              PG   93 min  \nAnimation, Adventure, Comedy
# 31            TV-Y   55 min  \nAnimation, Adventure, Comedy
# 32              PG  106 min    \nAction, Adventure, Mystery
# 33               G   77 min   \nAnimation, Adventure, Crime
# 34              PG  103 min     \nAction, Adventure, Sci-Fi
# 35            E10+     None    \nAction, Adventure, Fantasy
# 36           PG-13  109 min   \nAdventure, Fantasy, Mystery
# 37               G   75 min    \nAnimation, Family, Fantasy
# 38            None     None  \nAnimation, Adventure, Comedy
# 39              PG   91 min  \nAnimation, Adventure, Comedy
# 40            TV-G    3 min      \nAnimation, Short, Comedy
# 41            TV-G   22 min   \nAnimation, Short, Adventure
# 42            TV-G   22 min   \nAnimation, Short, Adventure
# 43            TV-G     None    \nComedy, Family, Reality-TV
# 44               G    8 min      \nAnimation, Short, Family
# 45               G    6 min      \nAnimation, Short, Family
# 46           TV-Y7   30 min  \nAnimation, Action, Adventure
# 47            None    7 min   \nAnimation, Short, Adventure
# 48       Not Rated   36 min  \nAnimation, Adventure, Comedy
# 49               G    7 min      \nAnimation, Short, Comedy
#
#    IMDB Rating    Votes Box Office Earnings  \
# 0    \n\n7.4\n   72,544             $61.56M
# 1    \n\n7.6\n  418,868            $107.83M
# 2    \n\n7.8\n  186,486            $434.04M
# 3    \n\n7.1\n  356,204            $244.08M
# 4    \n\n8.4\n  348,237            $209.73M
# 5    \n\n8.0\n  622,146            $206.45M
# 6    \n\n8.1\n  589,328            $356.46M
# 7    \n\n7.1\n  362,927            $237.28M
# 8    \n\n7.6\n  237,620            $608.58M
# 9    \n\n8.0\n  640,457            $261.44M
# 10   \n\n8.1\n  924,471            $380.84M
# 11   \n\n8.3\n  860,788            $191.80M
# 12   \n\n8.2\n  907,662            $293.00M
# 13   \n\n8.0\n  791,880            $289.92M
# 14   \n\n8.0\n  362,529            $217.35M
# 15   \n\n6.7\n   70,824            $152.90M
# 16   \n\n7.2\n  383,325            $218.08M
# 17   \n\n8.4\n  970,768            $223.81M
# 18   \n\n7.2\n  260,521            $162.80M
# 19   \n\n8.3\n  736,950            $415.00M
# 20   \n\n8.0\n  409,393            $218.97M
# 21   \n\n7.7\n  370,070            $189.42M
# 22   \n\n6.6\n  251,276             $73.08M
# 23   \n\n7.3\n  312,749            $268.49M
# 24        None
# 25   \n\n7.3\n  232,335            $486.30M
# 26   \n\n7.9\n  512,591            $245.85M
# 27   \n\n7.7\n  119,175             $15.09M
# 28   \n\n6.1\n  154,080            $191.45M
# 29   \n\n4.1\n   47,737             $20.92M
# 30   \n\n6.7\n   98,813            $123.09M
# 31   \n\n8.1\n   11,647
# 32   \n\n6.0\n   80,788             $37.76M
# 33   \n\n6.9\n   37,152             $27.93M
# 34   \n\n6.4\n   69,081             $70.12M
# 35   \n\n8.6\n    1,407
# 36   \n\n6.8\n   18,683             $19.74M
# 37   \n\n7.1\n   10,346
# 38        None
# 39   \n\n5.4\n    5,600             $28.37M
# 40   \n\n6.9\n      923
# 41   \n\n7.2\n    9,478
# 42   \n\n7.5\n   13,073
# 43   \n\n6.5\n      308
# 44   \n\n7.5\n   20,381
# 45   \n\n8.4\n   24,573
# 46   \n\n6.7\n    2,686
# 47   \n\n6.7\n    1,379
# 48   \n\n6.9\n    2,560
# 49   \n\n7.1\n    5,569
#
#                                           Description  \
# 0   Two elven brothers embark on a quest to bring ...
# 1   After being coerced into working for a crime b...
# 2   When a new toy called "Forky" joins Woody and ...
# 3   A hot-shot race-car named Lightning McQueen ge...
# 4   Aspiring musician Miguel, confronted with his ...
# 5   A rat who can cook makes an unusual alliance w...
# 6   After young Riley is uprooted from her Midwest...
# 7   Determined to make her own path in life, Princ...
# 8   The Incredibles hero family takes on a new mis...
# 9   A family of undercover superheroes, while tryi...
# 10  After his son is captured in the Great Barrier...
# 11  A cowboy doll is profoundly threatened and jea...
# 12  78-year-old Carl Fredricksen travels to Paradi...
# 13  In order to power the city, monsters have to s...
# 14  A kindhearted street urchin and a power-hungry...
# 15  Lightning McQueen sets out to prove to a new g...
# 16  A greedy film producer assembles a team of mov...
# 17  In the distant future, a small waste-collectin...
# 18  A misfit ant, looking for "warriors" to save h...
# 19  The toys are mistakenly delivered to a day-car...
# 20  A prince cursed to spend his days as a hideous...
# 21  A video game villain wants to be a hero and se...
# 22  Transported to Barsoom, a Civil War vet discov...
# 23  A look at the relationship between Mike Wazows...
# 24  A musician who has lost his passion for music ...
# 25  Friendly but forgetful blue tang Dory begins a...
# 26  When Woody is stolen by a toy collector, Buzz ...
# 27  A five-year-old boy develops a relationship wi...
# 28  Star race car Lightning McQueen and his pal Ma...
# 29  Two Brooklyn plumbers, Mario and Luigi, must t...
# 30  In a world where dinosaurs and humans live sid...
# 31  On a special inner city street, the inhabitant...
# 32  After New York City receives a series of attac...
# 33  The R.A.S. agents, Miss Bianca and Bernard, ra...
# 34  When the crew of the Enterprise learn of a Fed...
# 35  Believing light and darkness must remain in ba...
# 36  When assorted people start having inexplicable...
# 37  Tinkerbell wanders into the forbidden Winter w...
# 38  A Monsters inc series set 6 months after the M...
# 39  Following the events of the first movie, Surly...
# 40  Forky asks important questions about how the w...
# 41  It's a post-Christmas play-date and the toys h...
# 42  Woody and the gang are held up at a roadside m...
# 43  This live action series brings iconic characte...
# 44  A Chinese-Canadian woman suffering from empty ...
# 45  A mother bird tries to teach her little one ho...
# 46  The further adventures of Buzz Lightyear as a ...
# 47  Short that shows what happened to Bo Peep and ...
# 48  Cruise into the crazy adventures of Tow Mater ...
# 49  A fast food restaurant mini variant of Buzz fo...
#
#                                         Metascore             Director  \
# 0   \n61        \n        Metascore\n                      Dan Scanlon
# 1   \n86        \n        Metascore\n                     Edgar Wright
# 2   \n84        \n        Metascore\n                      Josh Cooley
# 3   \n73        \n        Metascore\n                    John Lasseter
# 4   \n81        \n        Metascore\n                      Lee Unkrich
# 5   \n96        \n        Metascore\n                        Brad Bird
# 6   \n94        \n        Metascore\n                      Pete Docter
# 7   \n69        \n        Metascore\n                     Mark Andrews
# 8   \n80        \n        Metascore\n                        Brad Bird
# 9   \n90        \n        Metascore\n                        Brad Bird
# 10  \n90        \n        Metascore\n                   Andrew Stanton
# 11  \n95        \n        Metascore\n                    John Lasseter
# 12  \n88        \n        Metascore\n                      Pete Docter
# 13  \n79        \n        Metascore\n                      Pete Docter
# 14  \n86        \n        Metascore\n                     Ron Clements
# 15  \n59        \n        Metascore\n                        Brian Fee
# 16  \n81        \n        Metascore\n                    Peter Jackson
# 17  \n95        \n        Metascore\n                   Andrew Stanton
# 18  \n77        \n        Metascore\n                    John Lasseter
# 19  \n92        \n        Metascore\n                      Lee Unkrich
# 20  \n95        \n        Metascore\n                   Gary Trousdale
# 21  \n72        \n        Metascore\n                       Rich Moore
# 22  \n51        \n        Metascore\n                   Andrew Stanton
# 23  \n65        \n        Metascore\n                      Dan Scanlon
# 24                                           None          Pete Docter
# 25  \n77        \n        Metascore\n                   Andrew Stanton
# 26  \n88        \n        Metascore\n                    John Lasseter
# 27  \n86        \n        Metascore\n                   Hayao Miyazaki
# 28  \n57        \n        Metascore\n                    John Lasseter
# 29                                           None       Annabel Jankel
# 30  \n66        \n        Metascore\n                       Peter Sohn
# 31                                           None           Jim Henson
# 32  \n64        \n        Metascore\n                     Kerry Conran
# 33  \n70        \n        Metascore\n                     Hendel Butoy
# 34  \n64        \n        Metascore\n                  Jonathan Frakes
# 35                                           None       Tetsuya Nomura
# 36  \n65        \n        Metascore\n                   Barry Levinson
# 37                                           None     Roberts Gannaway
# 38                                           None          Ben Feldman
# 39  \n36        \n        Metascore\n                      Cal Brunker
# 40                                           None            Tony Hale
# 41                                           None        Steve Purcell
# 42                                           None        Angus MacLane
# 43                                           None      David Greenberg
# 44                                           None            Domee Shi
# 45                                           None       Alan Barillaro
# 46                                           None    Patrick Warburton
# 47                                           None     Valerie LaPointe
# 48                                           None  Larry the Cable Guy
# 49                                           None        Angus MacLane
#
#                                                Actors
# 0   [Tom Holland, Chris Pratt, Julia Louis-Dreyfus...
# 1   [Ansel Elgort, Jon Bernthal, Jon Hamm, Eiza Go...
# 2      [Tom Hanks, Tim Allen, Annie Potts, Tony Hale]
# 3   [Joe Ranft, Owen Wilson, Bonnie Hunt, Paul New...
# 4   [Adrian Molina, Anthony Gonzalez, Gael García ...
# 5   [Jan Pinkava, Brad Garrett, Lou Romano, Patton...
# 6   [Ronnie Del Carmen, Amy Poehler, Bill Hader, L...
# 7   [Brenda Chapman, Steve Purcell, Kelly Macdonal...
# 8   [Craig T. Nelson, Holly Hunter, Sarah Vowell, ...
# 9   [Craig T. Nelson, Samuel L. Jackson, Holly Hun...
# 10  [Lee Unkrich, Albert Brooks, Ellen DeGeneres, ...
# 11    [Tom Hanks, Tim Allen, Don Rickles, Jim Varney]
# 12  [Bob Peterson, Edward Asner, Jordan Nagai, Joh...
# 13  [David Silverman, Lee Unkrich, Billy Crystal, ...
# 14  [John Musker, Scott Weinger, Robin Williams, L...
# 15  [Owen Wilson, Cristela Alonzo, Chris Cooper, N...
# 16  [Naomi Watts, Jack Black, Adrien Brody, Thomas...
# 17  [Ben Burtt, Elissa Knight, Jeff Garlin, Fred W...
# 18  [Andrew Stanton, Kevin Spacey, Dave Foley, Jul...
# 19    [Tom Hanks, Tim Allen, Joan Cusack, Ned Beatty]
# 20  [Kirk Wise, Paige O'Hara, Robby Benson, Jesse ...
# 21  [John C. Reilly, Jack McBrayer, Jane Lynch, Sa...
# 22  [Taylor Kitsch, Lynn Collins, Willem Dafoe, Sa...
# 23  [Billy Crystal, John Goodman, Steve Buscemi, H...
# 24    [Kemp Powers, Jamie Foxx, Tina Fey, Quest Love]
# 25  [Angus MacLane, Ellen DeGeneres, Albert Brooks...
# 26   [Ash Brannon, Lee Unkrich, Tom Hanks, Tim Allen]
# 27  [Cate Blanchett, Matt Damon, Liam Neeson, Tomo...
# 28  [Bradford Lewis, Owen Wilson, Larry the Cable ...
# 29  [Rocky Morton, Bob Hoskins, John Leguizamo, De...
# 30  [Jeffrey Wright, Frances McDormand, Maleah Nip...
# 31           [Frank Oz, Caroll Spinney, Jerry Nelson]
# 32  [Gwyneth Paltrow, Jude Law, Angelina Jolie, Gi...
# 33  [Mike Gabriel, Bob Newhart, Eva Gabor, John Ca...
# 34  [Patrick Stewart, Jonathan Frakes, Brent Spine...
# 35  [Tai Yasue, Masaru Oka, Haley Joel Osment, Dav...
# 36  [Nicholas Rowe, Alan Cox, Sophie Ward, Anthony...
# 37  [Peggy Holmes, Mae Whitman, Lucy Hale, Timothy...
# 38        [Billy Crystal, John Goodman, Bob Peterson]
# 39  [Will Arnett, Maya Rudolph, Bobby Cannavale, B...
# 40  [Bob Peterson, John Ratzenberger, Kristen Schaal]
# 41  [Tom Hanks, Tim Allen, Kristen Schaal, Kevin M...
# 42  [Tom Hanks, Tim Allen, Joan Cusack, Carl Weath...
# 43                    [Curtis Retherford, Zihan Zhao]
# 44  [Sindy Lau, Daniel Kai Lin, Sharmaine Yeoh, Ti...
# 45                                                 []
# 46     [Stephen Furst, Nicole Sullivan, Larry Miller]
# 47   [Annie Potts, Ally Maki, Jim Hanks, Emily Davis]
# 48   [Keith Ferguson, Elissa Knight, Lindsey Collins]
# 49  [Tom Hanks, Tim Allen, John Ratzenberger, Wall...

# %%
soup = get_page_contents('https://www.imdb.com/search/title/?companies=co0017902&start=51&ref_=adv_nxt')

df_dict2 = {}
df_dict2.update(create_dict())

# %%
df2 = pd.DataFrame(df_dict2)
df2

# %% [markdown]
# We will now combine the data from the two pages.

# %%
combined_data = pd.concat([df, df2], ignore_index = True, sort=True)

# %%
clean_df = combined_data

# %% [markdown]
# We will now clean the data.

# %%
clean_df['Year'] = clean_df['Year'].str.slice(start=-5, stop=-1)

# %%
clean_df['IMDB Rating'] = clean_df['IMDB Rating'].str.replace('\n',"")

# %%
clean_df['Metascore'] = clean_df['Metascore'].str.replace('\n',"")
clean_df['Metascore'] = clean_df['Metascore'].str.replace('Metascore',"")

# %%
clean_df['Runtime'] = clean_df['Runtime'].str.replace('min',"")

# %%
clean_df['Genre'] = clean_df['Genre'].str.slice(start=1)

# %%
clean_df['Studio'] = "Pixar Animation Studio"

# %%
clean_df.head()

# %%
clean_df = clean_df[['IMDB ID', 'Title', 'Year', 'Genre', 'Audience Rating', 'Description', 'Studio', 'Director', 'Actors', 'Box Office Earnings', 'Metascore', 'IMDB Rating', 'Votes']]

# %% [markdown]
# Now that we are done we will save the file.

# %%
save_path = r"C:\Users\Basil\Documents\Data Science\Projects\20200521 Disney\1. Original Data\Pixar Animation Studios.csv"
clean_df.to_csv(save_path)
