# %% [markdown]
# # Disney Web Scrape
#
# ### We will need to create datasets
#
# To gather the disney movie information we will scrape the IMDB movie database. We will begin by importinging beautiful soup, pandas and requests.

# %%
import bs4
import pandas as pd
import requests

# %% [markdown]
# We will create a function that will extract the html on a webpage into a BeautifulSoup object.

# %%
def get_page_contents(url):
    page = requests.get(url, headers={"Accept-Language": "en-US"})
    return bs4.BeautifulSoup(page.text, "html.parser")

# %%
def numeric_value(movie, tag, class_=None, order=None):
    if order:
        if len(movie.findAll(tag, class_)) > 1:
            to_extract = movie.findAll(tag, class_)[order]['data-value']
        else:
            to_extract = None
    else:
        to_extract = movie.find(tag, class_)['data-value']

    return to_extract

# %%
def text_value(movie, tag, class_=None):
    if movie.find(tag, class_):
        return movie.find(tag, class_).text
    else:
        return

# %%
def nested_text_value(movie, tag_1, class_1, tag_2, class_2, order=None):
    if not order:
        try:
            return movie.find(tag_1, class_1).find(tag_2, class_2).text
        except:
            return ""
    else:
        return [val.text for val in movie.find(tag_1, class_1).findAll(tag_2, class_2)[order]]

# %%
def extract_attribute(soup, tag_1, class_1='', tag_2='', class_2='',
                      text_attribute=True, order=None, nested=False):
    movies = soup.findAll('div', class_='lister-item-content')
    data_list = []
    for movie in movies:
        if text_attribute:
            if nested:
                data_list.append(nested_text_value(movie, tag_1, class_1, tag_2, class_2, order))
            else:
                data_list.append(text_value(movie, tag_1, class_1))
        else:
            data_list.append(numeric_value(movie, tag_1, class_1, order))

    return data_list

# %%
def create_dict():
    title = extract_attribute(soup, 'a')
    release = extract_attribute(soup, 'span', 'lister-item-year text-muted unbold')
    audience_rating = extract_attribute(soup, 'span', 'certificate')
    runtime = extract_attribute(soup, 'span', 'runtime')
    genre = extract_attribute(soup, 'span', 'genre')
    imdb_rating = extract_attribute(soup, 'span', 'ipl-rating-star__rating', False)
    metascore = extract_attribute(soup, 'div', 'inline-block ratings-metascore', False)
    description = extract_attribute(soup, 'p',"")
    
    movies = soup.findAll('div', class_='lister-item-content')
    imdb_id = []
    for movie in movies:
        imdb_id.append(soup.find('h3').a['href'].split('/')[2])
        
    movies = soup.findAll('div', class_='lister-item-content')
    votes = []
    earnings = []
    
    for movie in movies:
        movie_numbers = movie.findAll("span",attrs={"name": "nv"})
        if len(movie_numbers) == 2:
            votes.append(movie_numbers[0].text)
            earnings.append(movie_numbers[1].text)
        elif len(movie_numbers) == 1:
            votes.append(movie_numbers[0].text)
            earnings.append("")
        else:
            votes.append("")
            earnings.append("")
  
            
    
    df_dict = {'IMDB ID': imdb_id, 'Title': title, 'Year': release, 'Audience Rating': audience_rating,
           'Runtime': runtime, 'Genre': genre, 'IMDB Rating': imdb_rating,
           'Votes': votes, 'Box Office Earnings': earnings, 'Description' : description, 'Metascore': metascore}
    
    return df_dict

# %% [markdown]
# We will now run the function and connect to the IMDB Disney animations list I created. Contains all movies from all disney studios from Snow White and the Seven Dwarves (1937) to Onward (2020).

# %%
soup = get_page_contents('https://www.imdb.com/list/ls085145473/')

df_dict2 = {}
df_dict2.update(create_dict())

# %%
df = pd.DataFrame(df_dict2)
df
# Out:
#       IMDB ID                                              Title        Year  \
# 0   tt0029583                    Snow White and the Seven Dwarfs      (1937)
# 1   tt0029583                                          Pinocchio      (1940)
# 2   tt0029583                                           Fantasia      (1940)
# 3   tt0029583                               The Reluctant Dragon  (I) (1941)
# 4   tt0029583                                              Dumbo      (1941)
# 5   tt0029583                                              Bambi      (1942)
# 6   tt0029583                                     Saludos Amigos      (1942)
# 7   tt0029583                          Victory Through Air Power      (1943)
# 8   tt0029583                               The Three Caballeros      (1944)
# 9   tt0029583                                    Make Mine Music      (1946)
# 10  tt0029583                                  Song of the South      (1946)
# 11  tt0029583                                 Fun and Fancy Free      (1947)
# 12  tt0029583                                        Melody Time      (1948)
# 13  tt0029583                                So Dear to My Heart      (1948)
# 14  tt0029583             The Adventures of Ichabod and Mr. Toad      (1949)
# 15  tt0029583                                         Cinderella      (1950)
# 16  tt0029583                                    Treasure Island      (1950)
# 17  tt0029583                                Alice in Wonderland      (1951)
# 18  tt0029583         The Story of Robin Hood and His Merrie Men      (1952)
# 19  tt0029583                                          Peter Pan      (1953)
# 20  tt0029583                             The Sword and the Rose      (1953)
# 21  tt0029583                                  The Living Desert      (1953)
# 22  tt0029583                        Rob Roy: The Highland Rogue      (1953)
# 23  tt0029583                              The Vanishing Prairie      (1954)
# 24  tt0029583                       20,000 Leagues Under the Sea      (1954)
# 25  tt0029583           Davy Crockett: King of the Wild Frontier      (1955)
# 26  tt0029583                                 Lady and the Tramp      (1955)
# 27  tt0029583                                   The African Lion      (1955)
# 28  tt0029583                                The Littlest Outlaw      (1955)
# 29  tt0029583                         The Great Locomotive Chase      (1956)
# ..        ...                                                ...         ...
# 70  tt0029583                                      A Tiger Walks      (1964)
# 71  tt0029583                                  The Moon-Spinners      (1964)
# 72  tt0029583                                       Mary Poppins      (1964)
# 73  tt0029583                            Emil and the Detectives      (1964)
# 74  tt0029583                                    Those Calloways      (1965)
# 75  tt0029583                                 The Monkey's Uncle      (1965)
# 76  tt0029583                                     That Darn Cat!      (1965)
# 77  tt0029583                                 The Ugly Dachshund      (1966)
# 78  tt0029583                           Lt. Robin Crusoe, U.S.N.      (1966)
# 79  tt0029583                     The Fighting Prince of Donegal      (1966)
# 80  tt0029583                                   Follow Me, Boys!      (1966)
# 81  tt0029583                                  Monkeys, Go Home!      (1967)
# 82  tt0029583  The Adventures of Buckaroo Banzai Across the 8...      (1984)
# 83  tt0029583                           The Happiest Millionaire      (1967)
# 84  tt0029583                                   The Gnome-Mobile      (1967)
# 85  tt0029583                                    The Jungle Book      (1967)
# 86  tt0029583                       Charlie, the Lonesome Cougar      (1967)
# 87  tt0029583                                 Blackbeard's Ghost      (1968)
# 88  tt0029583    The One and Only, Genuine, Original Family Band      (1968)
# 89  tt0029583                                Never a Dull Moment      (1968)
# 90  tt0029583                 The Horse in the Gray Flannel Suit      (1968)
# 91  tt0029583                                       The Love Bug      (1968)
# 92  tt0029583                                             Smith!      (1969)
# 93  tt0029583                                             Rascal      (1969)
# 94  tt0029583                     The Computer Wore Tennis Shoes      (1969)
# 95  tt0029583                              King of the Grizzlies      (1970)
# 96  tt0029583                                       The Boatniks      (1970)
# 97  tt0029583                                     The Aristocats      (1970)
# 98  tt0029583                                   The Wild Country      (1970)
# 99  tt0029583                             The Barefoot Executive      (1971)
#
#    Audience Rating  Runtime                                          Genre  \
# 0         Approved   83 min       \nAnimation, Family, Fantasy
# 1                G   88 min        \nAnimation, Comedy, Family
# 2                G  125 min       \nAnimation, Family, Fantasy
# 3         Approved   74 min        \nAnimation, Comedy, Family
# 4                G   64 min         \nAnimation, Drama, Family
# 5                G   70 min         \nAnimation, Drama, Family
# 6         Approved   42 min      \nAnimation, Short, Adventure
# 7             None   70 min  \nDocumentary, Animation, History
# 8         Approved   71 min        \nAnimation, Comedy, Family
# 9         Approved   75 min     \nAnimation, Adventure, Comedy
# 10               G   94 min        \nAnimation, Comedy, Family
# 11        Approved   73 min     \nAnimation, Adventure, Comedy
# 12        Approved   75 min        \nAnimation, Comedy, Family
# 13          Passed   79 min         \nAnimation, Drama, Family
# 14        Approved   68 min        \nAnimation, Comedy, Family
# 15               G   74 min       \nAnimation, Family, Fantasy
# 16              PG   96 min                \nAdventure, Family
# 17               G   75 min     \nAnimation, Adventure, Family
# 18        Approved   84 min        \nAction, Adventure, Family
# 19               G   77 min     \nAnimation, Adventure, Family
# 20        Approved   92 min         \nAdventure, Drama, Family
# 21               G   69 min              \nFamily, Documentary
# 22        Approved   81 min      \nAdventure, Biography, Drama
# 23        Approved   71 min              \nDocumentary, Family
# 24               G  127 min         \nAdventure, Drama, Family
# 25        Approved   93 min         \nAdventure, Drama, Family
# 26               G   76 min     \nAnimation, Adventure, Comedy
# 27               G   75 min              \nFamily, Documentary
# 28       Not Rated   73 min                    \nDrama, Family
# 29        Approved   85 min        \nAction, Adventure, Family
# ..             ...      ...                                            ...
# 70        Approved   91 min                    \nFamily, Drama
# 71               G  118 min       \nAdventure, Family, Mystery
# 72               G  139 min          \nComedy, Family, Fantasy
# 73              PG   99 min            \nComedy, Family, Drama
# 74        Approved  131 min                    \nDrama, Family
# 75               G   87 min           \nFamily, Comedy, Sci-Fi
# 76        Approved  116 min            \nComedy, Crime, Family
# 77       Not Rated   93 min                   \nComedy, Family
# 78               G  110 min        \nAdventure, Comedy, Family
# 79       Not Rated  110 min     \nAdventure, Biography, Family
# 80        Approved  131 min                    \nDrama, Family
# 81          Passed  101 min                   \nComedy, Family
# 82              PG  103 min       \nAdventure, Comedy, Romance
# 83        Approved  141 min          \nComedy, Family, Musical
# 84        Approved   84 min       \nAdventure, Family, Fantasy
# 85               G   78 min     \nAnimation, Adventure, Family
# 86        Approved   75 min                \nAdventure, Family
# 87        Approved  106 min          \nComedy, Family, Fantasy
# 88          Passed  110 min            \nComedy, Drama, Family
# 89               G   99 min            \nFamily, Comedy, Crime
# 90               G  113 min            \nFamily, Comedy, Drama
# 91               G  108 min            \nComedy, Family, Sport
# 92               G  112 min           \nDrama, Family, Western
# 93               G   85 min                    \nDrama, Family
# 94               G   91 min           \nComedy, Family, Sci-Fi
# 95               G   93 min                  \nWestern, Family
# 96               G   99 min                   \nFamily, Comedy
# 97               G   78 min     \nAnimation, Adventure, Comedy
# 98               G  100 min        \nAction, Adventure, Comedy
# 99               G   96 min                   \nFamily, Comedy
#
#    IMDB Rating    Votes Box Office Earnings  \
# 0          7.6  176,896            $184.93M
# 1          7.4  127,391             $84.25M
# 2          7.8   86,686             $76.41M
# 3          6.9    2,605              $0.87M
# 4          7.2  116,679              $1.60M
# 5          7.3  128,039            $102.80M
# 6          6.1    5,108
# 7          6.6      846              $0.80M
# 8          6.4   11,917
# 9          6.3    3,588
# 10         7.1   11,077             $63.72M
# 11         6.6    6,750
# 12         6.4    4,721
# 13         6.8    1,251
# 14           7   12,342
# 15         7.3  141,944             $85.00M
# 16         6.9    6,883
# 17         7.4  125,720
# 18         6.7    1,424              $4.58M
# 19         7.3  122,873             $87.40M
# 20         6.5      727
# 21         7.5    1,227
# 22         6.3      488
# 23         7.4      448
# 24         7.2   28,510             $28.20M
# 25           7    3,500
# 26         7.3  119,375             $93.60M
# 27         7.2      326
# 28         6.1      194
# 29         6.9    1,023
# ..         ...      ...                 ...
# 70         6.5      272
# 71         6.7    2,128
# 72         7.8  154,107            $102.27M
# 73         6.1      488
# 74         6.7      513
# 75         6.1      734
# 76         6.8    5,803             $28.06M
# 77         6.7    3,433             $13.52M
# 78           6    1,209             $22.57M
# 79         6.2      328
# 80         7.2    2,062
# 81         5.9      434
# 82         6.3   23,449              $6.25M
# 83         6.8    1,741
# 84         6.6    1,928
# 85         7.6  162,117            $141.84M
# 86         6.9      777
# 87         6.9    5,069             $10.90M
# 88         6.5      772
# 89         6.2      600
# 90         6.5      852
# 91         6.5   13,987              $5.09M
# 92         5.9      188
# 93         6.5      393
# 94         6.1    4,364              $0.73M
# 95         5.8      142
# 96         5.5      658             $18.61M
# 97         7.1   90,917             $37.68M
# 98         6.4      246
# 99           6    1,640
#
#                                           Description  \
# 0   \n    Exiled into the dangerous forest by her ...
# 1   \n    A living puppet, with the help of a cric...
# 2   \n    A collection of animated interpretations...
# 3   \n    Humorist Robert Benchley learns about th...
# 4   \n    Ridiculed because of his enormous ears, ...
# 5   \n    The story of a young deer growing up in ...
# 6   \n    Disney animators tour South America and ...
# 7   \n    An animated documentary promoting of the...
# 8   \n    Donald receives his birthday gifts, whic...
# 9   \n    Animation done to contemporary popular m...
# 10  \n    The kindly story-teller Uncle Remus tell...
# 11  \n    Jiminy Cricket hosts two Disney animated...
# 12  \n    An anthology of animated vignettes set t...
# 13  \n    This heartwarming classic tells the tale...
# 14  \n    An animated adaptation of "The Wind in t...
# 15  \n    When Cinderella's cruel stepmother preve...
# 16  \n    The treasure seeking adventures of young...
# 17  \n    Alice stumbles into the world of Wonderl...
# 18  \n    With King Richard away at the crusades, ...
# 19  \n    Wendy and her brothers are whisked away ...
# 20  \n    During the reign of Henry VIII, Mary Tud...
# 21  \n    Documentary of the lives of flora and fa...
# 22  \n    The wartime adventures of Scotish highla...
# 23  \n    Story of the American Prairie as it was ...
# 24  \n    A ship sent to investigate a wave of mys...
# 25  \n    American frontiersman Davy Crockett figh...
# 26  \n    The romantic tale of a sheltered uptown ...
# 27  \n    Experience the thrill of the hunt and th...
# 28  \n    Little Pablito is the ten year old son o...
# 29  \n    During the Civil War Union spy Andrews a...
# ..                                                ...
# 70  \n    A tiger escapes from a circus truck as i...
# 71  \n    A teenager encounters romance, intrigue ...
# 72  \n    In turn of the century London, a magical...
# 73  \n    Emil goes to Berlin to see his grandmoth...
# 74  \n    Story of Cam Calloway and his family, wh...
# 75  \n    Midvale College is in fear of losing its...
# 76  \n    After a kidnapped bank teller uses a nei...
# 77  \n    The Garrisons live with a Great Dane who...
# 78  \n    Lt. Robin Crusoe is a navy pilot who bai...
# 79  \n    After inheriting his father's title, the...
# 80  \n    Lem Siddons is part of a traveling band ...
# 81  \n    Henry Dussard, a young American, inherit...
# 82  \n    Adventurer, brain surgeon, rock musician...
# 83  \n    A happy and unbelievably lucky young Iri...
# 84  \n    An eccentric millionaire and his grandch...
# 85  \n    Bagheera the Panther and Baloo the Bear ...
# 86  \n    When a cougar raised by a group of logge...
# 87  \n    On the Carolina coast, Godolphin College...
# 88  \n    The Bower Family Band petitions the Demo...
# 89  \n    Actor Jack Albany, who plays gangsters o...
# 90  \n    Frederick Bolton has to solve two proble...
# 91  \n    A race car driver becomes a champion wit...
# 92  \n    When the Indian Jimmyboy is accused of m...
# 93  \n    A young boy's summer vacation is brighte...
# 94  \n    At Medfield College, an accident with a ...
# 95  \n    Ernest T. Seton, an American artist and ...
# 96  \n    Young and awkward, U.S. Coast Guard Ensi...
# 97  \n    With the help of a smooth talking tomcat...
# 98  \n    A family leaves city life to take posses...
# 99  \n    A young man who works in the mailroom at...
#
#                                     Metascore
# 0   \n95        \n        Metascore\n
# 1   \n99        \n        Metascore\n
# 2   \n96        \n        Metascore\n
# 3                                        None
# 4   \n96        \n        Metascore\n
# 5   \n91        \n        Metascore\n
# 6   \n60        \n        Metascore\n
# 7                                        None
# 8   \n85        \n        Metascore\n
# 9   \n60        \n        Metascore\n
# 10  \n54        \n        Metascore\n
# 11  \n66        \n        Metascore\n
# 12  \n69        \n        Metascore\n
# 13                                       None
# 14  \n74        \n        Metascore\n
# 15  \n85        \n        Metascore\n
# 16  \n89        \n        Metascore\n
# 17  \n68        \n        Metascore\n
# 18  \n64        \n        Metascore\n
# 19  \n76        \n        Metascore\n
# 20                                       None
# 21  \n69        \n        Metascore\n
# 22                                       None
# 23                                       None
# 24  \n83        \n        Metascore\n
# 25                                       None
# 26  \n78        \n        Metascore\n
# 27                                       None
# 28                                       None
# 29                                       None
# ..                                        ...
# 70                                       None
# 71                                       None
# 72  \n88        \n        Metascore\n
# 73                                       None
# 74                                       None
# 75                                       None
# 76  \n71        \n        Metascore\n
# 77                                       None
# 78                                       None
# 79                                       None
# 80                                       None
# 81                                       None
# 82  \n70        \n        Metascore\n
# 83                                       None
# 84                                       None
# 85  \n65        \n        Metascore\n
# 86                                       None
# 87  \n71        \n        Metascore\n
# 88                                       None
# 89                                       None
# 90                                       None
# 91  \n48        \n        Metascore\n
# 92                                       None
# 93                                       None
# 94  \n54        \n        Metascore\n
# 95                                       None
# 96                                       None
# 97  \n66        \n        Metascore\n
# 98                                       None
# 99  \n55        \n        Metascore\n
#
# [100 rows x 11 columns]

# %% [markdown]
# The first page looks good. There are a total of 749 titles. We will pull all 8 pages of the list. Then we will combine them.

# %%
soup = get_page_contents('https://www.imdb.com/list/ls085145473/?sort=list_order,asc&st_dt=&mode=detail&page=2')

df_dict2 = {}
df_dict2.update(create_dict())
df2 = pd.DataFrame(df_dict2)

# %%
soup = get_page_contents('https://www.imdb.com/list/ls085145473/?sort=list_order,asc&st_dt=&mode=detail&page=3')

df_dict2 = {}
df_dict2.update(create_dict())
df3 = pd.DataFrame(df_dict2)

# %%
soup = get_page_contents('https://www.imdb.com/list/ls085145473/?sort=list_order,asc&st_dt=&mode=detail&page=4')

df_dict2 = {}
df_dict2.update(create_dict())
df4 = pd.DataFrame(df_dict2)

# %%
soup = get_page_contents('https://www.imdb.com/list/ls085145473/?sort=list_order,asc&st_dt=&mode=detail&page=5')

df_dict2 = {}
df_dict2.update(create_dict())
df5 = pd.DataFrame(df_dict2)

# %%
soup = get_page_contents('https://www.imdb.com/list/ls085145473/?sort=list_order,asc&st_dt=&mode=detail&page=6')

df_dict2 = {}
df_dict2.update(create_dict())
df6 = pd.DataFrame(df_dict2)

# %%
soup = get_page_contents('https://www.imdb.com/list/ls085145473/?sort=list_order,asc&st_dt=&mode=detail&page=7')

df_dict2 = {}
df_dict2.update(create_dict())
df7 = pd.DataFrame(df_dict2)

# %%
soup = get_page_contents('https://www.imdb.com/list/ls085145473/?sort=list_order,asc&st_dt=&mode=detail&page=8')

df_dict2 = {}
df_dict2.update(create_dict())
df8 = pd.DataFrame(df_dict2)

# %%
combined_data = pd.concat([df, df2, df3, df4, df5, df6, df7, df8], ignore_index = True, sort=True)

# %% [markdown]
# Now that we have a full list we will clean the data. We will rename the headers and sort them in the order we desire.

# %%
clean_df = combined_data

# %%
clean_df['Year'] = clean_df['Year'].str.slice(start=-5, stop=-1)

# %%
clean_df['IMDB Rating'] = clean_df['IMDB Rating'].str.replace('\n',"")

# %%
clean_df['Metascore'] = clean_df['Metascore'].str.replace('\n',"")
clean_df['Metascore'] = clean_df['Metascore'].str.replace('Metascore',"")

# %%
clean_df['Runtime'] = clean_df['Runtime'].str.replace('min',"")

# %%
clean_df['Genre'] = clean_df['Genre'].str.slice(start=1)

# %%
clean_df.head()
# Out:
#   Audience Rating Box Office Earnings  \
# 0        Approved            $184.93M
# 1               G             $84.25M
# 2               G             $76.41M
# 3        Approved              $0.87M
# 4               G              $1.60M
#
#                                          Description  \
# 0  \n    Exiled into the dangerous forest by her ...
# 1  \n    A living puppet, with the help of a cric...
# 2  \n    A collection of animated interpretations...
# 3  \n    Humorist Robert Benchley learns about th...
# 4  \n    Ridiculed because of his enormous ears, ...
#
#                                     Genre    IMDB ID IMDB Rating  \
# 0  Animation, Family, Fantasy              tt0029583         7.6
# 1   Animation, Comedy, Family              tt0029583         7.4
# 2  Animation, Family, Fantasy              tt0029583         7.8
# 3   Animation, Comedy, Family              tt0029583         6.9
# 4    Animation, Drama, Family              tt0029583         7.2
#
#                     Metascore Runtime                            Title  \
# 0  95                             83   Snow White and the Seven Dwarfs
# 1  99                             88                         Pinocchio
# 2  96                            125                          Fantasia
# 3                        None     74              The Reluctant Dragon
# 4  96                             64                             Dumbo
#
#      Votes  Year
# 0  176,896  1937
# 1  127,391  1940
# 2   86,686  1940
# 3    2,605  1941
# 4  116,679  1941

# %%
clean_df = clean_df[['IMDB ID', 'Title', 'Year', 'Genre', 'Audience Rating', 'Description', 'Box Office Earnings', 'Metascore', 'IMDB Rating', 'Votes']]

# %% [markdown]
# Now that the cleaning is done we will save it as a csv file.

# %%
save_path = r"C:\Users\Basil\Documents\Data Science\Projects\20200521 Disney\1. Original Data\Walt Disney Studios.csv"
clean_df.to_csv(save_path)
